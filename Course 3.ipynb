# %% [markdown]
# **This notebook write to caculate NPV.**
# - NPV, or net present value, is how much an investment is worth throughout its lifetime, discounted to today’s value.
# ![image.png](attachment:05007c1b-1df0-4b96-8bb1-66140ad15b17.png)

# %% [markdown]
# # Excersice 1

# %% [markdown]
# ![image.png](attachment:0bc590ef-e172-4c89-aff0-04a988be295b.png)

# %% [markdown]
# ## Project B

# %%
from sympy import symbols, solve, N

r = symbols('r')
solutions = solve(100/(1+r) + 200/((1+r)**2) + 300/((1+r)**3) + 400/((1+r)**4) + 500/((1+r)**5) - 1000, r)

# To get the numerical approximations of the roots
numeric_solutions = [sol.evalf() for sol in solutions]
print(numeric_solutions)
# Out:
# [0.120057619541963, -1.66025445755359 - 0.434630456172873*I, -1.66025445755359 + 0.434630456172873*I, -0.849774352217396 - 0.831783984027733*I, -0.849774352217396 + 0.831783984027733*I]

# %%
r = 0.1199999
100/(1+r) + 200/((1+r)**2) + 300/((1+r)**3) + 400/((1+r)**4) + 500/((1+r)**5) - 1000
# Out:
# 0.17953444709564792

# %%
r = 0.1
100/(1+r) + 200/((1+r)**2) + 300/((1+r)**3) + 400/((1+r)**4) + 500/((1+r)**5) - 1000
# Out:
# 65.25883105351704

# %% [markdown]
# ## Project C

# %%
from sympy import symbols, solve, N

r = symbols('r')
solutions = solve(400/(1+r) + 400/((1+r)**2) + 400/((1+r)**3) + 400/((1+r)**4) + 400/((1+r)**5) - 1000, r)

# To get the numerical approximations of the roots
numeric_solutions = [sol.evalf() for sol in solutions]
print(numeric_solutions)
# Out:
# [0.286492902497676, -1.60035798122654 - 0.400895940215382*I, -1.60035798122654 + 0.400895940215382*I, -0.842888470022294 - 0.756259332293902*I, -0.842888470022294 + 0.756259332293902*I]

# %%
r = 0.2865
400/(1+r) + 400/((1+r)**2) + 400/((1+r)**3) + 400/((1+r)**4) + 400/((1+r)**5) - 1000
# Out:
# -0.013844662197584512

# %%
r = 0.1
400/(1+r) + 400/((1+r)**2) + 400/((1+r)**3) + 400/((1+r)**4) + 400/((1+r)**5) - 1000
# Out:
# 516.3147077633789

# %% [markdown]
# ## Project D

# %%
from sympy import symbols, solve, N

r = symbols('r')
solutions = solve(500/(1+r) + 500/((1+r)**2) + 10000/((1+r)**3) - 1000, r)

# To get the numerical approximations of the roots
numeric_solutions = [sol.evalf() for sol in solutions]
print(numeric_solutions)
# Out:
# [-1.95882843085139 - 1.79356748138401*I, -1.95882843085139 + 1.79356748138401*I, 1.41765686170277]

# %%
r = 1.417655
500/(1+r) + 500/((1+r)**2) + 10000/((1+r)**3) - 1000
# Out:
# 0.0019257557360106148

# %%
r = 0.1
500/(1+r) + 500/((1+r)**2) + 10000/((1+r)**3) - 1000
# Out:
# 7380.916604057098

# %% [markdown]
# # Excercise 2

# %% [markdown]
# ![image.png](attachment:999f4741-be07-4c4a-bc0e-9c6f7901dc5f.png)

# %%
from sympy import symbols, solve, N

r = symbols('r')
solutions = solve(35/(1+r) + 32/((1+r)**2) + 28/((1+r)**3) + 23/((1+r)**4) + 25/((1+r)**5) - 100, r)
solutions
# To get the numerical approximations of the roots
numeric_solutions = [sol.evalf() for sol in solutions]
print(numeric_solutions)
# Out:
# [0.143703285331426, -1.55383512553048 - 0.382481413861585*I, -1.55383512553048 + 0.382481413861585*I, -0.843016517135237 - 0.676656286938281*I, -0.843016517135237 + 0.676656286938281*I]

# %%
r = 0.1437
35/(1+r) + 32/((1+r)**2) + 28/((1+r)**3) + 23/((1+r)**4) + 25/((1+r)**5) - 100
# Out:
# 0.0007276890699330352

# %%
r = 0.1
35/(1+r) + 32/((1+r)**2) + 28/((1+r)**3) + 23/((1+r)**4) + 25/((1+r)**5) - 100
# Out:
# 10.533619785037018
